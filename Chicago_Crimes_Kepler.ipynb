# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Crimes.csv')
data.head()
# Out:
#       CASE#     DATE  OF OCCURRENCE                 BLOCK  IUCR  \
# 0  JD163753  02/24/2020 08:15:00 PM  031XX W LEXINGTON ST  1153
# 1  JC320782  06/24/2019 06:20:00 PM   041XX S DREXEL BLVD  0820
# 2  JC497784  11/03/2019 11:40:00 AM      032XX N CLARK ST  0860
# 3  JC270482  05/19/2019 11:00:00 AM       018XX S WOOD ST  1152
# 4  JC459410  10/04/2019 06:10:00 AM   004XX S LA SALLE ST  0560
#
#    PRIMARY DESCRIPTION                SECONDARY DESCRIPTION  \
# 0   DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1                THEFT                       $500 AND UNDER
# 2                THEFT                         RETAIL THEFT
# 3   DECEPTIVE PRACTICE                ILLEGAL USE CASH CARD
# 4              ASSAULT                               SIMPLE
#
#              LOCATION DESCRIPTION ARREST DOMESTIC  BEAT  WARD FBI CD  \
# 0                             NaN      N        N  1134  24.0     11
# 1   RESIDENTIAL YARD (FRONT/BACK)      N        N   214   4.0     06
# ...

# %%
data.shape
# Out:
# (248419, 17)

# %%
data.isnull().sum()
# Out:
# CASE#                        0
# DATE  OF OCCURRENCE          0
# BLOCK                        0
#  IUCR                        0
#  PRIMARY DESCRIPTION         0
#  SECONDARY DESCRIPTION       0
#  LOCATION DESCRIPTION      980
# ARREST                       0
# DOMESTIC                     0
# BEAT                         0
# WARD                        13
# FBI CD                       0
# X COORDINATE              1269
# Y COORDINATE              1269
# LATITUDE                  1269
# LONGITUDE                 1269
# LOCATION                  1269
# dtype: int64
